# %% [markdown]
# <h1><center><font color='blue'>Regresión Lineal 1D: Entrenando 2 parámetros con Mini-Batch Gradient Descent </center></font></h1>

# %% [markdown]
# <h2>Objetivo</h2><ul><li> Usar las funciones incorporadas de PyTorch para crear un modelo</li></ul>

# %% [markdown]
# <h2>Tabla de contenido</h2>
#
#
# <ul>
#     <li><a href="#Makeup_Data">Crear algunos datos </a></li>
#     <li><a href="#Model_Cost">Crear el modelo y la funcion de costo al estilo PyTorch </a></li>
#     <li><a href="#BGD">Entrenar el modelo: Batch Gradient Descent</a></li>
# </ul>
#
# <hr>

# %% [markdown]
# <h2>Preparación</h2>

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# These are the libraries we are going to use in the lab.

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %% [markdown]
# La clase <code>plot_error_surfaces</code> nos ayudará a visualizar el espacio de datos y el de parámetros durante el entrenamiento.

# %%
# class for ploting  

class plot_error_surfaces(object):
    
    # Constructor
    def __init__(self, w_range, b_range, X, Y, n_samples = 30, go = True):
        W = np.linspace(-w_range, w_range, n_samples)
        B = np.linspace(-b_range, b_range, n_samples)
        w, b = np.meshgrid(W, B)    
        Z = np.zeros((30, 30))
        count1 = 0
        self.y = Y.numpy()
        self.x = X.numpy()
        for w1, b1 in zip(w, b):
            count2 = 0
            for w2, b2 in zip(w1, b1):
                Z[count1, count2] = np.mean((self.y - w2 * self.x + b2) ** 2)
                count2 += 1
            count1 += 1
        self.Z = Z
        self.w = w
        self.b = b
        self.W = []
        self.B = []
        self.LOSS = []
        self.n = 0
        if go == True:
            plt.figure()
            plt.figure(figsize = (7.5, 5))
            plt.axes(projection = '3d').plot_surface(self.w, self.b, self.Z, rstride = 1, cstride = 1, cmap = 'viridis', edgecolor = 'none')
            plt.title('Loss Surface')
            plt.xlabel('w')
            plt.ylabel('b')
            plt.show()
            plt.figure()
            plt.title('Loss Surface Contour')
            plt.xlabel('w')
            plt.ylabel('b')
            plt.contour(self.w, self.b, self.Z)
            plt.show()
            
    # Setter
    def set_para_loss(self, model, loss):
        self.n = self.n + 1
        self.LOSS.append(loss)
        self.W.append(list(model.parameters())[0].item())
        self.B.append(list(model.parameters())[1].item())
    
    # Plot diagram
    def final_plot(self): 
        ax = plt.axes(projection = '3d')
        ax.plot_wireframe(self.w, self.b, self.Z)
        ax.scatter(self.W, self.B, self.LOSS, c = 'r', marker = 'x', s = 200, alpha = 1)
        plt.figure()
        plt.contour(self.w, self.b, self.Z)
        plt.scatter(self.W, self.B, c = 'r', marker = 'x')
        plt.xlabel('w')
        plt.ylabel('b')
        plt.show()
        
    # Plot diagram    
    def plot_ps(self):
        plt.subplot(121)
        plt.ylim()
        plt.plot(self.x, self.y, 'ro', label = "training points")
        plt.plot(self.x, self.W[-1] * self.x + self.B[-1], label = "estimated line")
        plt.xlabel('x')
        plt.ylabel('y')
        plt.ylim((-10, 15))
        plt.title('Data Space Iteration: ' + str(self.n))
        plt.subplot(122)
        plt.contour(self.w, self.b, self.Z)
        plt.scatter(self.W, self.B, c = 'r', marker = 'x')
        plt.title('Loss Surface Contour Iteration' + str(self.n) )
        plt.xlabel('w')
        plt.ylabel('b')
        plt.show()

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Makeup_Data">Crear algunos datos</h2>

# %% [markdown]
# Importamos librerías y establecemos la semilla aleatoria.

# %%
# Import libraries and set random seed

import torch
from torch.utils.data import Dataset, DataLoader
torch.manual_seed(1)

# %% [markdown]
# Generamos valores entre -3 y 3 para crear una recta con pendiente 1 y sesgo -1. Es la recta a estimar. Agregamos ruido a los datos:

# %%
# Create Data Class

class Data(Dataset):
    
    # Constructor
    def __init__(self):
        self.x = torch.arange(-3, 3, 0.1).view(-1, 1)
        self.f = 1 * self.x - 1
        self.y = self.f + 0.1 * torch.randn(self.x.size())
        self.len = self.x.shape[0]
        
    # Getter
    def __getitem__(self,index):    
        return self.x[index],self.y[index]
    
    # Get Length
    def __len__(self):
        return self.len

# %% [markdown]
# Creamos un objeto dataset:

# %%
# Create dataset object

dataset = Data()

# %% [markdown]
# Graficamos los datos y la recta:

# %%
# Plot the data

plt.plot(dataset.x.numpy(), dataset.y.numpy(), 'rx', label = 'y')
plt.plot(dataset.x.numpy(), dataset.f.numpy(), label = 'f')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Model_Cost">Creamos el modelo y la función de pérdida total (Costo)</h2>

# %% [markdown]
# Creamos una clase linear_regression (regresión lineal)

# %%
# Create a linear regression model class

from torch import nn, optim

class linear_regression(nn.Module):
    
    # Constructor
    def __init__(self, input_size, output_size):
        super(linear_regression, self).__init__()
        self.linear = nn.Linear(input_size, output_size)
        
    # Prediction
    def forward(self, x):
        yhat = self.linear(x)
        return yhat

# %% [markdown]
# Usamos las funciones incorporadas de PyTorch para crear una función de criterio; esto calcula la pérdida total o costo.

# %%
# Build in cost function

criterion = nn.MSELoss()

# %% [markdown]
# Creamos un objeto linear_regression y un objeto optimizer; el objeto optimizer utilizará el objeto linear_regression.

# %%
# Create optimizer

model = linear_regression(1,1)
optimizer = optim.SGD(model.parameters(), lr = 0.01)

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[0.3636]], requires_grad=True),
#  Parameter containing:
#  tensor([0.4957], requires_grad=True)]

# %% [markdown]
# Recuerde que para construir un optimizer debe brindar un iterable conteniendo los parámetros, es decir, debe proveer <code> model.parameters()</code> como entrada al constructor

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter2/2.4model_optmiz.png" width="100" alt="Model Optimizer" />

# %% [markdown]
# Al igual que model, optimizer tiene un diccionario de estado:

# %%
optimizer.state_dict()
# Out:
# {'state': {},
#  'param_groups': [{'lr': 0.01,
#    'momentum': 0,
#    'dampening': 0,
#    'weight_decay': 0,
#    'nesterov': False,
#    'params': [0, 1]}]}

# %% [markdown]
# Muchas de las claves corresponden a optimizers más avanzados.

# %% [markdown]
# Creamos un objeto <code>Dataloader</code>:

# %%
# Create Dataloader object

trainloader = DataLoader(dataset = dataset, batch_size = 1)

# %% [markdown]
# PyTorch inicializa los parámetros de su modelo. Si usamos esos parámetros, el resultado no será muy perspicaz ya que la convergencia se dará muy rápido. Así que los inicializaremos de modo que la convergencia demore más.

# %%
# Customize the weight and bias

model.state_dict()['linear.weight'][0] = -15
model.state_dict()['linear.bias'][0] = -10

# %% [markdown]
# Creamos un objeto para graficar:

# %%
# Create plot surface object

get_surface = plot_error_surfaces(15, 13, dataset.x, dataset.y, 30, go = False)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="BGD">Entrenando el modelo vía Batch Gradient Descent</h2>

# %% [markdown]
# Ejecutamos 10 epochs de stochastic gradient descent: <b>bug</b> el espacio de datos se encuentra 1 iteración por delante del de parámetros.

# %%
# Train Model

def train_model_BGD(iter):
    for epoch in range(iter):
        for x,y in trainloader:
            yhat = model(x)
            loss = criterion(yhat, y)
            get_surface.set_para_loss(model, loss.tolist())          
            optimizer.zero_grad()
            loss.backward()

            optimizer.step()
        get_surface.plot_ps()


train_model_BGD(10)

# %%
model.state_dict()
# Out:
# OrderedDict([('linear.weight', tensor([[0.9932]])),
#              ('linear.bias', tensor([-1.0174]))])

# %% [markdown]
# Usemos el siguiente diagrama para clarificar el proceso.  El modelo toma <code> x </code> para producir una estimación de <code> yhat </code>, luego se comparará con el <code> y </code> real con la función de pérdida.

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter2/2.4get_loss.png" width="400" alt="Old Model Cost diagram" />

# %% [markdown]
# Cuando llamamos a <code>backward()</code> sobre la función de pérdida, manejará la diferenciación. Al llamar al método step en el objeto optimizer, se actualizarán los parámetros. La conexión se muestra en la figura siguiente:

# %% [markdown]
# <img src = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter2/2.4update_param.png" width="500" alt="Model Cost with optimizer" />

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Práctica</h3>

# %% [markdown]
# Entrene el modelo vía BGD, con lr=0.1. Use optimizer y las variables dadas.

# %%
# Practice: Train the model via BGD using optimizer

model = linear_regression(1,1)
model.state_dict()['linear.weight'][0] = -15
model.state_dict()['linear.bias'][0] = -10
get_surface = plot_error_surfaces(15, 13, dataset.x, dataset.y, 30, go = False)
#
def my_train_model(iter):
    for epoch in range(iter):
        for x,y in trainloader:
            yhat = model(x)
            loss = criterion(yhat, y)
            get_surface.set_para_loss(model, loss.tolist()) 
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        get_surface.plot_ps()

train_model_BGD(10)
